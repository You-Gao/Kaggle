# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from datetime import datetime
from scipy.stats import skew  # for some statistics
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax
from sklearn.linear_model import ElasticNetCV, LassoCV, RidgeCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error
from mlxtend.regressor import StackingCVRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


# Any results you write to the current directory are saved as output.

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print ("Data is loaded!")
# Out:
# Data is loaded!

# %%
print ("Train: ",train.shape[0],"sales, and ",train.shape[1],"features")
print ("Test: ",test.shape[0],"sales, and ",test.shape[1],"features")
# Out:
# Train:  1460 sales, and  81 features
# Test:  1459 sales, and  80 features

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# # Exploratory Analysis/Data Validation

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
# 3       Norm     1Fam     2Story            6            6       1998
# 4       Norm   TwnhsE     1Story            8            5       1992
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 2          1998     Gable  CompShg     VinylSd     VinylSd       None
# 3          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       108.0        TA        TA     CBlock       TA       TA           No
# 2         0.0        TA        TA      PConc       Gd       TA           No
# 3        20.0        TA        TA      PConc       TA       TA           No
# 4         0.0        Gd        TA      PConc       Gd       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Rec       468.0          LwQ       144.0      270.0        882.0
# 1          ALQ       923.0          Unf         0.0      406.0       1329.0
# 2          GLQ       791.0          Unf         0.0      137.0        928.0
# 3          GLQ       602.0          Unf         0.0      324.0        926.0
# 4          ALQ       263.0          Unf         0.0     1017.0       1280.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        TA          Y      SBrkr       896         0             0
# 1    GasA        TA          Y      SBrkr      1329         0             0
# 2    GasA        Gd          Y      SBrkr       928       701             0
# 3    GasA        Ex          Y      SBrkr       926       678             0
# 4    GasA        Ex          Y      SBrkr      1280         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        896           0.0           0.0         1         0             2
# 1       1329           0.0           0.0         1         1             3
# 2       1629           0.0           0.0         2         1             3
# 3       1604           0.0           0.0         2         1             3
# 4       1280           0.0           0.0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          TA             5        Typ           0         NaN
# 1             1          Gd             6        Typ           0         NaN
# 2             1          TA             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             5        Typ           0         NaN
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       1961.0          Unf         1.0       730.0         TA
# 1     Attchd       1958.0          Unf         1.0       312.0         TA
# 2     Attchd       1997.0          Fin         2.0       482.0         TA
# 3     Attchd       1998.0          Fin         2.0       470.0         TA
# 4     Attchd       1992.0          RFn         2.0       506.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y         140            0              0          0
# 1         TA          Y         393           36              0          0
# 2         TA          Y         212           34              0          0
# 3         TA          Y         360           36              0          0
# 4         TA          Y           0           82              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0          120         0    NaN  MnPrv         NaN        0       6    2010
# 1            0         0    NaN    NaN        Gar2    12500       6    2010
# 2            0         0    NaN  MnPrv         NaN        0       3    2010
# 3            0         0    NaN    NaN         NaN        0       6    2010
# 4          144         0    NaN    NaN         NaN        0       1    2010
#
#   SaleType SaleCondition
# 0       WD        Normal
# 1       WD        Normal
# 2       WD        Normal
# 3       WD        Normal
# 4       WD        Normal

# %%
quantitative = [f for f in train.columns if train.dtypes[f] != 'object']
quantitative.remove('SalePrice')
quantitative.remove('Id')
qualitative = [f for f in train.columns if train.dtypes[f] == 'object']

# %%
test_normality = lambda x: stats.shapiro(x.fillna(0))[1] < 0.01
normal = pd.DataFrame(train[quantitative])
normal = normal.apply(test_normality)

print(not normal.any())
# Out:
# False

# %%
def encode(frame, feature):
    ordering = pd.DataFrame()
    ordering['val'] = frame[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = frame[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()
    
    for cat, o in ordering.items():
        frame.loc[frame[feature] == cat, feature+'_E'] = o
        
    
qual_encoded = []
for q in qualitative:  
    encode(train, q)
    qual_encoded.append(q+'_E')
print(qual_encoded)
# Out:
# ['MSZoning_E', 'Street_E', 'Alley_E', 'LotShape_E', 'LandContour_E', 'Utilities_E', 'LotConfig_E', 'LandSlope_E', 'Neighborhood_E', 'Condition1_E', 'Condition2_E', 'BldgType_E', 'HouseStyle_E', 'RoofStyle_E', 'RoofMatl_E', 'Exterior1st_E', 'Exterior2nd_E', 'MasVnrType_E', 'ExterQual_E', 'ExterCond_E', 'Foundation_E', 'BsmtQual_E', 'BsmtCond_E', 'BsmtExposure_E', 'BsmtFinType1_E', 'BsmtFinType2_E', 'Heating_E', 'HeatingQC_E', 'CentralAir_E', 'Electrical_E', 'KitchenQual_E', 'Functional_E', 'FireplaceQu_E', 'GarageType_E', 'GarageFinish_E', 'GarageQual_E', 'GarageCond_E', 'PavedDrive_E', 'PoolQC_E', 'Fence_E', 'MiscFeature_E', 'SaleType_E', 'SaleCondition_E']

# %%
def spearman(frame, features):
    spr = pd.DataFrame()
    spr['feature'] = features
    spr['spearman'] = [frame[f].corr(frame['SalePrice'], 'spearman') for f in features]
    spr = spr.sort_values('spearman')
    plt.figure(figsize=(6, 0.25*len(features)))
    sns.barplot(data=spr, y='feature', x='spearman', orient='h')
    
features = quantitative + qual_encoded
spearman(train, features)

# %%
plt.figure(1)
corr = train[quantitative+['SalePrice']].corr()
sns.heatmap(corr)
plt.figure(2)
corr = train[qual_encoded+['SalePrice']].corr()
sns.heatmap(corr)
plt.figure(3)
corr = pd.DataFrame(np.zeros([len(quantitative)+1, len(qual_encoded)+1]), index=quantitative+['SalePrice'], columns=qual_encoded+['SalePrice'])
for q1 in quantitative+['SalePrice']:
    for q2 in qual_encoded+['SalePrice']:
        corr.loc[q1, q2] = train[q1].corr(train[q2])
sns.heatmap(corr)
# Out:
# <AxesSubplot: >

# %%
print(len(quantitative) + len(qual_encoded))
# Out:
# 79

# %%
features = quantitative + qual_encoded
model = TSNE(n_components=2, random_state=0, perplexity=50)
X = train[features].fillna(0.).values
tsne = model.fit_transform(X)

std = StandardScaler()
s = std.fit_transform(X)
pca = PCA(n_components=30)
pca.fit(s)
pc = pca.transform(s)
kmeans = KMeans(n_clusters=5)
kmeans.fit(pc)

fr = pd.DataFrame({'tsne1': tsne[:,0], 'tsne2': tsne[:, 1], 'cluster': kmeans.labels_})
sns.lmplot(data=fr, x='tsne1', y='tsne2', hue='cluster', fit_reg=False)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# 0.7541410063598802

# %% [markdown]
# Feature Engineering

# %%
train.drop(['Id'], axis=1, inplace=True)
test.drop(['Id'], axis=1, inplace=True)

# %%
train = train[train.GrLivArea < 4500]
train.reset_index(drop=True, inplace=True)
train["SalePrice"] = np.log1p(train["SalePrice"])
y = train['SalePrice'].reset_index(drop=True)

# %%
train_features = train.drop(['SalePrice'], axis=1)
test_features = test
features = pd.concat([train_features, test_features]).reset_index(drop=True)

# %%
features['MSSubClass'] = features['MSSubClass'].apply(str)
features['YrSold'] = features['YrSold'].astype(str)
features['MoSold'] = features['MoSold'].astype(str)
features['Functional'] = features['Functional'].fillna('Typ') 
features['Electrical'] = features['Electrical'].fillna("SBrkr") 
features['KitchenQual'] = features['KitchenQual'].fillna("TA") 
features["PoolQC"] = features["PoolQC"].fillna("None")
features['Exterior1st'] = features['Exterior1st'].fillna(features['Exterior1st'].mode()[0]) 
features['Exterior2nd'] = features['Exterior2nd'].fillna(features['Exterior2nd'].mode()[0])
features['SaleType'] = features['SaleType'].fillna(features['SaleType'].mode()[0])

# %%
features.head()
# Out:
#   MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0         60       RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1         20       RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2         60       RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3         70       RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4         60       RL         84.0    14260   Pave   NaN      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd       None         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng       None         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ       706.0
# 1     CBlock       Gd       TA           Gd          ALQ       978.0
# 2      PConc       Gd       TA           Mn          GLQ       486.0
# 3     BrkTil       TA       Gd           No          ALQ       216.0
# 4      PConc       Gd       TA           Av          GLQ       655.0
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf         0.0      150.0        856.0    GasA        Ex
# 1          Unf         0.0      284.0       1262.0    GasA        Ex
# 2          Unf         0.0      434.0        920.0    GasA        Ex
# 3          Unf         0.0      540.0        756.0    GasA        Gd
# 4          Unf         0.0      490.0       1145.0    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         2         1             3             1
# 1           0.0           1.0         2         0             3             1
# 2           1.0           0.0         2         1             3             1
# 3           1.0           0.0         1         0             3             1
# 4           1.0           0.0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  \
# 0          Gd             8        Typ           0         NaN     Attchd
# 1          TA             6        Typ           1          TA     Attchd
# 2          Gd             6        Typ           1          TA     Attchd
# 3          Gd             7        Typ           1          Gd     Detchd
# 4          Gd             9        Typ           1          TA     Attchd
#
#    GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond  \
# 0       2003.0          RFn         2.0       548.0         TA         TA
# 1       1976.0          RFn         2.0       460.0         TA         TA
# 2       2001.0          RFn         2.0       608.0         TA         TA
# 3       1998.0          Unf         3.0       642.0         TA         TA
# 4       2000.0          RFn         3.0       836.0         TA         TA
#
#   PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0          Y           0           61              0          0            0
# 1          Y         298            0              0          0            0
# 2          Y           0           42              0          0            0
# 3          Y           0           35            272          0            0
# 4          Y         192           84              0          0            0
#
#    PoolArea PoolQC Fence MiscFeature  MiscVal MoSold YrSold SaleType  \
# 0         0   None   NaN         NaN        0      2   2008       WD
# 1         0   None   NaN         NaN        0      5   2007       WD
# 2         0   None   NaN         NaN        0      9   2008       WD
# 3         0   None   NaN         NaN        0      2   2006       WD
# 4         0   None   NaN         NaN        0     12   2008       WD
#
#   SaleCondition  MSZoning_E  Street_E  Alley_E  LotShape_E  LandContour_E  \
# 0        Normal         4.0       2.0      NaN         1.0            2.0
# 1        Normal         4.0       2.0      NaN         1.0            2.0
# 2        Normal         4.0       2.0      NaN         2.0            2.0
# 3       Abnorml         4.0       2.0      NaN         2.0            2.0
# 4        Normal         4.0       2.0      NaN         2.0            2.0
#
#    Utilities_E  LotConfig_E  LandSlope_E  Neighborhood_E  Condition1_E  \
# 0          2.0          1.0          1.0            17.0           5.0
# 1          2.0          2.0          1.0            21.0           3.0
# 2          2.0          1.0          1.0            17.0           5.0
# 3          2.0          3.0          1.0            18.0           5.0
# 4          2.0          2.0          1.0            25.0           5.0
#
#    Condition2_E  BldgType_E  HouseStyle_E  RoofStyle_E  RoofMatl_E  \
# 0           5.0         5.0           7.0          2.0         3.0
# 1           5.0         5.0           6.0          2.0         3.0
# 2           5.0         5.0           7.0          2.0         3.0
# 3           5.0         5.0           7.0          2.0         3.0
# 4           5.0         5.0           7.0          2.0         3.0
#
#    Exterior1st_E  Exterior2nd_E  MasVnrType_E  ExterQual_E  ExterCond_E  \
# 0           12.0           13.0           3.0          3.0          4.0
# 1            5.0            6.0           2.0          2.0          4.0
# 2           12.0           13.0           3.0          3.0          4.0
# 3            6.0            9.0           2.0          2.0          4.0
# 4           12.0           13.0           3.0          3.0          4.0
#
#    Foundation_E  BsmtQual_E  BsmtCond_E  BsmtExposure_E  BsmtFinType1_E  \
# 0           6.0         3.0         3.0             1.0             6.0
# 1           3.0         3.0         3.0             4.0             4.0
# 2           6.0         3.0         3.0             2.0             6.0
# 3           2.0         2.0         4.0             1.0             4.0
# 4           6.0         3.0         3.0             3.0             6.0
#
#    BsmtFinType2_E  Heating_E  HeatingQC_E  CentralAir_E  Electrical_E  \
# 0             5.0        6.0          5.0           2.0           5.0
# 1             5.0        6.0          5.0           2.0           5.0
# 2             5.0        6.0          5.0           2.0           5.0
# 3             5.0        6.0          4.0           2.0           5.0
# 4             5.0        6.0          5.0           2.0           5.0
#
#    KitchenQual_E  Functional_E  FireplaceQu_E  GarageType_E  GarageFinish_E  \
# 0            3.0           7.0            NaN           5.0             2.0
# 1            2.0           7.0            3.0           5.0             2.0
# 2            3.0           7.0            3.0           5.0             2.0
# 3            3.0           7.0            4.0           2.0             1.0
# 4            3.0           7.0            3.0           5.0             2.0
#
#    GarageQual_E  GarageCond_E  PavedDrive_E  PoolQC_E  Fence_E  MiscFeature_E  \
# 0           3.0           5.0           3.0       NaN      NaN            NaN
# 1           3.0           5.0           3.0       NaN      NaN            NaN
# 2           3.0           5.0           3.0       NaN      NaN            NaN
# 3           3.0           5.0           3.0       NaN      NaN            NaN
# 4           3.0           5.0           3.0       NaN      NaN            NaN
#
#    SaleType_E  SaleCondition_E
# 0         5.0              5.0
# 1         5.0              5.0
# 2         5.0              5.0
# 3         5.0              2.0
# 4         5.0              5.0

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    features[col] = features[col].fillna(0)

for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    features[col] = features[col].fillna('None')

for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    features[col] = features[col].fillna('None')

features['MSZoning'] = features.groupby('MSSubClass')['MSZoning'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
objects = []
for i in features.columns:
    if features[i].dtype == object:
        objects.append(i)
features.update(features[objects].fillna('None'))

features['LotFrontage'] = features.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerics = []
for i in features.columns:
    if features[i].dtype in numeric_dtypes:
        numerics.append(i)
features.update(features[numerics].fillna(0))

# %%
numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerics2 = []
for i in features.columns:
    if features[i].dtype in numeric_dtypes:
        numerics2.append(i)
skew_features = features[numerics2].apply(lambda x: skew(x)).sort_values(ascending=False)

high_skew = skew_features[skew_features > 0.5]
skew_index = high_skew.index

for i in skew_index:
    features[i] = boxcox1p(features[i], boxcox_normmax(features[i] + 1))
# Out:
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:4427: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:4464: NearConstantInputWarning: An input array is nearly constant; the computed correlation coefficient may be inaccurate.
#   warnings.warn(stats.NearConstantInputWarning(msg))

# %%
features = features.drop(['Utilities', 'Street', 'PoolQC',], axis=1)

features['YrBltAndRemod']=features['YearBuilt']+features['YearRemodAdd']
features['TotalSF']=features['TotalBsmtSF'] + features['1stFlrSF'] + features['2ndFlrSF']

features['Total_sqr_footage'] = (features['BsmtFinSF1'] + features['BsmtFinSF2'] +
                                 features['1stFlrSF'] + features['2ndFlrSF'])

features['Total_Bathrooms'] = (features['FullBath'] + (0.5 * features['HalfBath']) +
                               features['BsmtFullBath'] + (0.5 * features['BsmtHalfBath']))

features['Total_porch_sf'] = (features['OpenPorchSF'] + features['3SsnPorch'] +
                              features['EnclosedPorch'] + features['ScreenPorch'] +
                              features['WoodDeckSF'])

# %%
features['haspool'] = features['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
features['has2ndfloor'] = features['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
features['hasgarage'] = features['GarageArea'].apply(lambda x: 1 if x > 0 else 0)
features['hasbsmt'] = features['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)
features['hasfireplace'] = features['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

# %%
final_features = pd.get_dummies(features).reset_index(drop=True)
final_features.shape
# Out:
# (2917, 376)

# %%
X = final_features.iloc[:len(y), :]
X_sub = final_features.iloc[len(y):, :]
X.shape, y.shape, X_sub.shape
# Out:
# ((1458, 376), (1458,), (1459, 376))

# %%
kfolds = KFold(n_splits = 10, shuffle = True, random_state = 42)

def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

def cv_rmse(model, X=X):
    rmse = np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv=kfolds))
    return (rmse)

# %%
alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alphas2 = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

# %%
alpha_r = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alpha_l = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
elastic_nets = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
svrs = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

# %%
ridge = make_pipeline(RobustScaler(), RidgeCV(alphas = alpha_r, cv = kfolds))
lasso = make_pipeline(RobustScaler(), LassoCV(alphas = alpha_l, cv = kfolds))
elastic_nets = make_pipeline(RobustScaler(), ElasticNetCV(alphas = e_alphas, cv = kfolds, l1_ratio=e_l1ratio))
svr = make_pipeline(RobustScaler(), SVR(C= 20, epsilon= 0.008, gamma=0.0003,))

# %%
gbr = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05, max_depth=4, max_features='sqrt', min_samples_leaf=15, min_samples_split=10, loss='huber', random_state =42)

# %%
lightgbm = LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=5000,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       )

# %%
xgboost = XGBRegressor(learning_rate=0.01,n_estimators=3460,
                                     max_depth=3, min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27,
                                     reg_alpha=0.00006)

# %%
stack_gen = StackingCVRegressor(regressors=(ridge, lasso, elastic_nets, gbr, xgboost, lightgbm),
                                meta_regressor=xgboost,
                                use_features_in_secondary=True)

# %%
score = cv_rmse(ridge)
print("RIDGE: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(lasso)
print("LASSO: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(elastic_nets)
print("elastic net: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(svr)
print("SVR: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(lightgbm)
print("lightgbm: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(gbr)
print("gbr: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )

score = cv_rmse(xgboost)
print("xgboost: {:.4f} ({:.4f})\n".format(score.mean(), score.std()), datetime.now(), )
# Out:
# RIDGE: 0.1080 (0.0157)
#  2023-01-17 07:37:28.782730
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13125143897791425, tolerance: 0.018925230920342005
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5245917242554086, tolerance: 0.018511883702771226
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.910816820478539, tolerance: 0.01884066078848668
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2962941928429865, tolerance: 0.018568747892145264
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.683769561647595, tolerance: 0.018449593110313123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17834625222296108, tolerance: 0.01825224776208794
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06807707274771424, tolerance: 0.01825224776208794
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2392530463796927, tolerance: 0.01896003117840311
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2760084245304242, tolerance: 0.0187208062125657
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3415438861986857, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5692280160050327, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2322496252500379, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4812339918983026, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1440417614576166, tolerance: 0.01881076429496946
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.057667735196273995, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44210357812945134, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2618536727638787, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38532772684362815, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5790421173785276, tolerance: 0.019123044161822065
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.411209796578035, tolerance: 0.01947626543225349
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09402942439092499, tolerance: 0.019261617344594452
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2262143858166521, tolerance: 0.018060607598357557
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18472669915980688, tolerance: 0.018249231978764532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16097123952417114, tolerance: 0.019063156185623067
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02604117257801164, tolerance: 0.019092824625606197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.375670219523223, tolerance: 0.019184953743782634
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12953334332217104, tolerance: 0.018990750551951343
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22889614908133993, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19951181862809264, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1437238747956897, tolerance: 0.01867212594518391
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23229253643485226, tolerance: 0.018954721644637268
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34047939903397406, tolerance: 0.01909368210439396
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.374501635057416, tolerance: 0.018876530313566495
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3464316876832694, tolerance: 0.01948151229712613
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18883104989290267, tolerance: 0.019542600304011257
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09906118041607037, tolerance: 0.018628714612309714
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2701882037192469, tolerance: 0.01945286145465763
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19341506728999747, tolerance: 0.018901601834647647
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0232800886784794, tolerance: 0.019555945106280673
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6736464495927219, tolerance: 0.018585756726900795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.016392151587798, tolerance: 0.018728102201253954
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16096158550331374, tolerance: 0.017989988755745395
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1490483928682078, tolerance: 0.018724097186247943
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13742596019691966, tolerance: 0.018302703347587403
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18657593199369416, tolerance: 0.018467698579225138
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08617731473851009, tolerance: 0.018438900175194752
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0746933924872124, tolerance: 0.018200240379937532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2362285113158249, tolerance: 0.018744063727614484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12362838443322843, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.354219259645326, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4098987531251197, tolerance: 0.018703278163380292
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029066232089324018, tolerance: 0.019129107841468672
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4001488240247557, tolerance: 0.018933462215833963
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2860434115225221, tolerance: 0.018407514439502604
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16721040360577177, tolerance: 0.018423969928131657
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08380364726034273, tolerance: 0.0188809827155465
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05099891603792095, tolerance: 0.0188099259754704
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2683755369447054, tolerance: 0.018407610116485888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1633515763974493, tolerance: 0.01865002418563265
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029290383265760056, tolerance: 0.01930140633536979
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16060403517991872, tolerance: 0.01895501862838238
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26860920576958414, tolerance: 0.01925144992729077
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09073529015611825, tolerance: 0.019429219754505785
#   model = cd_fast.enet_coordinate_descent_gram(
# LASSO: 0.1072 (0.0153)
#  2023-01-17 07:37:37.649433
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15125660456135215, tolerance: 0.01884066078848668
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08458574439236699, tolerance: 0.018697256331983204
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08799891111668146, tolerance: 0.01884066078848668
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08869109407966214, tolerance: 0.018838953935048683
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033025554459449324, tolerance: 0.01884066078848668
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07056425222959284, tolerance: 0.018838953935048683
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05354606699503428, tolerance: 0.018449593110313123
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4738631408151912, tolerance: 0.0187208062125657
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09320441805029311, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16513093043478833, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08055763276755812, tolerance: 0.01881076429496946
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1908175287204097, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5808052873232743, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0733038475766623, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18018731172616853, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.059074014633762495, tolerance: 0.01881076429496946
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17024079077192766, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.524535881827564, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01972301038681934, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19997683273901679, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05384219873626783, tolerance: 0.01881076429496946
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10870034451302057, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4463135772550322, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18432574834853366, tolerance: 0.01825224776208794
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14007839039673264, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20531188485580376, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020326892830068388, tolerance: 0.01881076429496946
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07910428996117869, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38500532620664263, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18094599737491723, tolerance: 0.01825224776208794
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29890021212630735, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2303913102264863, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06148219585328896, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28889875024980594, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17834475949852902, tolerance: 0.01825224776208794
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3415438859078037, tolerance: 0.018591288846191982
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23222936912293868, tolerance: 0.019029003517939427
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.057667733811094024, tolerance: 0.018802943425906538
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26187603095776346, tolerance: 0.019218263141628868
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11610753875917901, tolerance: 0.01866763525076451
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05436808531324111, tolerance: 0.01866763525076451
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03448223439035836, tolerance: 0.018060607598357557
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032833492711919376, tolerance: 0.01866763525076451
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13692042733450815, tolerance: 0.018060607598357557
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22254430654959645, tolerance: 0.018060607598357557
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22486577916409978, tolerance: 0.018060607598357557
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10431415036382674, tolerance: 0.019184953743782634
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01858867605485237, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2632648137067761, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.058400848247380566, tolerance: 0.019302200915504313
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.040784878420638826, tolerance: 0.019184953743782634
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2518643435259822, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.051013447625657626, tolerance: 0.019302200915504313
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27762593018295245, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03954471460720832, tolerance: 0.019302200915504313
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26724484385171277, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02874062465845295, tolerance: 0.019302200915504313
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29689135301323777, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23559175154150314, tolerance: 0.018478835077445795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13021432018160795, tolerance: 0.019052689659024246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06009755051335297, tolerance: 0.019052689659024246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023068592180090164, tolerance: 0.018728102201253954
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06545583314330372, tolerance: 0.01777302241015631
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0291472272885116, tolerance: 0.01777302241015631
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025708621091844464, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07291044209221553, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11018987159690319, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12362838436837009, tolerance: 0.018844527762344254
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13074130883153146, tolerance: 0.018407514439502604
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026793418456085405, tolerance: 0.0188809827155465
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10754640102485258, tolerance: 0.018407514439502604
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13021610365302472, tolerance: 0.018407514439502604
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019038163190490565, tolerance: 0.018407514439502604
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.051297853127163506, tolerance: 0.0188099259754704
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05099611295004536, tolerance: 0.0188099259754704
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07838231649631133, tolerance: 0.019429219754505785
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03498774387984582, tolerance: 0.019230757814242744
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.053349551216676616, tolerance: 0.019429219754505785
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04152870105624906, tolerance: 0.019429219754505785
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03903120413529848, tolerance: 0.019230757814242744
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025085534991282188, tolerance: 0.019429219754505785
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030921232883407868, tolerance: 0.019230757814242744
#   model = cd_fast.enet_coordinate_descent_gram(
# elastic net: 0.1072 (0.0153)
#  2023-01-17 07:38:11.172165
# SVR: 0.1079 (0.0179)
#  2023-01-17 07:38:14.162282
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# lightgbm: 0.1129 (0.0153)
#  2023-01-17 07:38:39.371727
# gbr: 0.1139 (0.0152)
#  2023-01-17 07:39:54.794500
# [07:39:54] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:01] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:08] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:15] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:22] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:29] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:36] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:43] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:50] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:40:58] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# xgboost: 0.1110 (0.0148)
#  2023-01-17 07:41:05.093239

# %%
print('START Fit')

print('stack_gen')
stack_gen_model = stack_gen.fit(np.array(X), np.array(y))

print('elasticnet')
elastic_model_full_data = elastic_nets.fit(X, y)

print('Lasso')
lasso_model_full_data = lasso.fit(X, y)

print('Ridge')
ridge_model_full_data = ridge.fit(X, y)

print('Svr')
svr_model_full_data = svr.fit(X, y)

print('GradientBoosting')
gbr_model_full_data = gbr.fit(X, y)

print('xgboost')
xgb_model_full_data = xgboost.fit(X, y)

print('lightgbm')
lgb_model_full_data = lightgbm.fit(X, y)
# Out:
# START Fit
# stack_gen
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.56023146867068, tolerance: 0.01649249122189588
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19812142072577466, tolerance: 0.01625270398577323
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2682301545105128, tolerance: 0.01675153540282064
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8268427308609612, tolerance: 0.01675153540282064
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15145773283933117, tolerance: 0.01691346937897104
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16923139539112775, tolerance: 0.01691346937897104
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10473892815212693, tolerance: 0.016659144038000433
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18310378957490503, tolerance: 0.01661465801626543
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05015473917103197, tolerance: 0.016154107197312983
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01833310381614872, tolerance: 0.016154107197312983
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1444354356434694, tolerance: 0.016811904259321907
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24441707650393596, tolerance: 0.016811904259321907
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5092815986615626, tolerance: 0.016236763265612002
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06995409970044086, tolerance: 0.016206188469893242
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3187939008296379, tolerance: 0.016206188469893242
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17140797069091374, tolerance: 0.016170979054434615
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.034769465252011855, tolerance: 0.016280290735811116
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03622199319330033, tolerance: 0.016884512587506898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4395755982438594, tolerance: 0.016550999143860823
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2293911419848378, tolerance: 0.016951031858434173
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4019797290347755, tolerance: 0.01655218561129191
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08964961479953093, tolerance: 0.01690586651712417
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3360767071777033, tolerance: 0.016921479658156664
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01660682592455931, tolerance: 0.016316816409052876
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024578013414513933, tolerance: 0.016919359879091062
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2505199460926182, tolerance: 0.016552974135077874
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28708454265931316, tolerance: 0.01726287819690531
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9473441607591777, tolerance: 0.01726287819690531
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03134335524616283, tolerance: 0.017322249752713653
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5680793179397536, tolerance: 0.017306551174034825
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017769127043518296, tolerance: 0.017345295714239047
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8504526741924616, tolerance: 0.017345295714239047
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5312943304774542, tolerance: 0.016892774829521867
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06378455943075423, tolerance: 0.01695751604146873
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7601925601924142, tolerance: 0.017073109939460474
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022203116981151183, tolerance: 0.016819991053263355
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07726976285221099, tolerance: 0.016819991053263355
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5842826464715039, tolerance: 0.016819991053263355
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07877028938820096, tolerance: 0.017149195961699743
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.6872645891148568, tolerance: 0.01636180696601879
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2036112135956127, tolerance: 0.01680554950197544
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6057975234899171, tolerance: 0.016843604732973146
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07031335150971874, tolerance: 0.017159302553022532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.049463341465997956, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3725519749758828, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12417121102107131, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08283615071459671, tolerance: 0.017159302553022532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11173200658860516, tolerance: 0.017002543568343253
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.041058588443118715, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3475140649768793, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11228616378224565, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023082730074893476, tolerance: 0.017159302553022532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06809060859989113, tolerance: 0.017002543568343253
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1512182712861123, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0996269105108265, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02993967413725862, tolerance: 0.017159302553022532
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.043762729878380924, tolerance: 0.017002543568343253
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9265459842782517, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08713967257628763, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.041528342609158386, tolerance: 0.017002543568343253
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7860064019443049, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0834360296031722, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.038498350955509686, tolerance: 0.017002543568343253
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7662241870157107, tolerance: 0.017301687626914516
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08335828182665317, tolerance: 0.016670145280516184
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16340858053793372, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2512975567118265, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06555940551665707, tolerance: 0.016646135310190244
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3621486336379327, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1266481799104806, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0929774242122128, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.055808118006805074, tolerance: 0.016646135310190244
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26810516430598064, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0804587330300901, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5730955376747975, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.043616726792498284, tolerance: 0.016646135310190244
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021545405008784435, tolerance: 0.016606361829563144
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17145797090562898, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024365346049775027, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13969385380893762, tolerance: 0.016874306535677817
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023100758208724592, tolerance: 0.016646135310190244
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0956455965127958, tolerance: 0.016606361829563144
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0682100998448476, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.054553964276903955, tolerance: 0.016606361829563144
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.045548557266748446, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.049248191897200755, tolerance: 0.016606361829563144
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04055240741823596, tolerance: 0.01587929206838948
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16481760981213434, tolerance: 0.017556202775296764
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12434431070554108, tolerance: 0.017007355773186836
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09031917731969052, tolerance: 0.01657242624951316
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09888390775817602, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1809385126220544, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14918748299512874, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02891697363400425, tolerance: 0.01657242624951316
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0860600134188454, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1279231148369835, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0748780213877085, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10198004289061302, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06098284895414885, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033452709998582186, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07216603308983949, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04758085625983277, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05157558530789785, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06282878392223257, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.048601397132044255, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.042718761861229027, tolerance: 0.017167563310199415
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.055369885491741044, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05672411858706905, tolerance: 0.017518392126928534
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04261111314677368, tolerance: 0.017139998826047713
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30489956721700295, tolerance: 0.01723756674437753
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0676679970761116, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22471439445220298, tolerance: 0.01723756674437753
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07047961774202793, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08707215033686833, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21386133203595215, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026605643820454716, tolerance: 0.01720056095473859
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03259417892445171, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024095215353977295, tolerance: 0.01720056095473859
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025570718363717937, tolerance: 0.017012511933473425
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.163231774532008, tolerance: 0.016151564426123928
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3100080646275254, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2065679443316233, tolerance: 0.015575022922149297
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17319655424245006, tolerance: 0.015808358693510126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35263926431901993, tolerance: 0.016309084236906742
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05553098835998593, tolerance: 0.016151564426123928
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3381026391191728, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19033927865347966, tolerance: 0.015808358693510126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27587992919706483, tolerance: 0.016309084236906742
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3661524963042915, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21098967004188474, tolerance: 0.015808358693510126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1959013677338648, tolerance: 0.016309084236906742
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4016250645307595, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21921889785542348, tolerance: 0.015808358693510126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4211632091825912, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.426077330494131, tolerance: 0.01620403867631808
#   model = cd_fast.enet_coordinate_descent_gram(
# [07:42:32] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:42:37] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:42:41] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:42:46] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [07:42:51] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [07:43:09] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1505881154015274, tolerance: 0.020866375694064566
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20187085704939722, tolerance: 0.02111724116294148
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03283076945490038, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.735210032703737, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4421003290442638, tolerance: 0.020395184715549932
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8726620863195391, tolerance: 0.020802357974604037
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03711161939044594, tolerance: 0.020866375694064566
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07672211435168919, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07721807724353624, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07031804472705616, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04985971973179737, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03596444230191942, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032830777919636844, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# [07:43:33] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [LightGBM] [Warning] feature_fraction is set=0.2, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=1.0 will be ignored. Current value: bagging_fraction=0.75
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# elasticnet
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03711161939044594, tolerance: 0.020866375694064566
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07672211435168919, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07721807724353624, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07031804472705616, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04985971973179737, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03596444230191942, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032830777919636844, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# Lasso
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1505881154015274, tolerance: 0.020866375694064566
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20187085704939722, tolerance: 0.02111724116294148
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03283076945490038, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.735210032703737, tolerance: 0.021202321665448883
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4421003290442638, tolerance: 0.020395184715549932
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8726620863195391, tolerance: 0.020802357974604037
#   model = cd_fast.enet_coordinate_descent_gram(
# Ridge
# Svr
# GradientBoosting
# xgboost
# [07:44:00] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# lightgbm

# %%
def blend_models_predict(X):
    return ((0.1 * elastic_model_full_data.predict(X)) + \
            (0.05 * lasso_model_full_data.predict(X)) + \
            (0.1 * ridge_model_full_data.predict(X)) + \
            (0.1 * svr_model_full_data.predict(X)) + \
            (0.1 * gbr_model_full_data.predict(X)) + \
            (0.15 * xgb_model_full_data.predict(X)) + \
            (0.1 * lgb_model_full_data.predict(X)) + \
            (0.3 * stack_gen_model.predict(np.array(X))))

# %%
print(rmsle(y, blend_models_predict(X)))
# Out:
# 0.05826868174352907

# %%
submission = pd.read_csv('sample_submission.csv')

submission.iloc[:,1] = np.floor(np.expm1(blend_models_predict(X_sub)))

submission.to_csv('submission.csv', index=False)

# %%
print(blend_models_predict(X_sub))
# Out:
# [11.07472795 11.2035592  11.39200776 ... 11.33774178 11.01041872
#  11.51322075]
