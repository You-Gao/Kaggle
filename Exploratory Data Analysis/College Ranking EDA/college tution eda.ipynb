# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
college_df = pd.read_csv('2022 US College Rankings.csv')
print(college_df.shape)
print(college_df.columns)
college_df.head(5)
# Out:
# (161, 4)
# Index(['College Name', 'Adjusted Rank', 'Tuition', 'Enrollment Numbers'], dtype='object')
#                             College Name  Adjusted Rank  Tuition  \
# 0                   Princeton University              1    56010
# 1                    Columbia University              2    63530
# 2                     Harvard University              2    55587
# 3  Massachusetts Institute of Technology              2    55878
# 4                        Yale University              5    59950
#
#    Enrollment Numbers
# 0                4773
# 1                6170
# 2                5222
# 3                4361
# 4                4703

# %%
college_df[college_df['College Name'] == 'University of Virginia']
# Out:
#               College Name  Adjusted Rank  Tuition  Enrollment Numbers
# 25  University of Virginia             25    53666               17311

# %%
sns.scatterplot(x = 'Adjusted Rank', y = 'Tuition', data = college_df)
# Out:
# <AxesSubplot: xlabel='Adjusted Rank', ylabel='Tuition'>

# %%
sns.scatterplot(x = 'Tuition', y = 'Enrollment Numbers', data = college_df)
# Out:
# <AxesSubplot: xlabel='Tuition', ylabel='Enrollment Numbers'>
