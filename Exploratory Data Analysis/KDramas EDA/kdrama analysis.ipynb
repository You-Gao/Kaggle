# %%
# Import Basic Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# File c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:60
#      58 from matplotlib import _docstring
#      59 from matplotlib.backend_bases import FigureCanvasBase, MouseButton
# ---> 60 from matplotlib.figure import Figure, FigureBase, figaspect
#      61 from matplotlib.gridspec import GridSpec, SubplotSpec
#      62 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# File c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\figure.py:26
#      23 import numpy as np
#      25 import matplotlib as mpl
# ---> 26 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      27 from matplotlib.artist import (
#      28     Artist, allow_rasterization, _finalize_rasterization)
#      29 from matplotlib.backend_bases import (
#      30     DrawEvent, FigureCanvasBase, NonGuiException, MouseButton, _get_renderer)
#
# File c:\Users\commo\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\projections\__init__.py:56
#       1 """
#       2 Non-separable transforms that map from data space to screen space.
#       3
#    (...)
#      52 `matplotlib.projections.polar` may also be of interest.
#      53 """
#      55 from .. import axes, _docstring
# ---> 56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
#      58 from mpl_toolkits.mplot3d import Axes3D
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1012, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:673, in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
# Load Data

kdrama = pd.read_csv('kdrama.csv')

# %%
kdrama.head()
# Out:
#                   Name  \
# 0       Move to Heaven
# 1       Flower of Evil
# 2    Hospital Playlist
# 3  Hospital Playlist 2
# 4            My Mister
#
#                     Aired Date  Year of release  \
# 0                 May 14, 2021             2021
# 1  Jul 29, 2020 - Sep 23, 2020             2020
# 2  Mar 12, 2020 - May 28, 2020             2020
# 3  Jun 17, 2021 - Sep 16, 2021             2021
# 4  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  \
# 0          Netflix                Friday
# 1              tvN   Wednesday, Thursday
# 2   Netflix,  tvN               Thursday
# 3   Netflix,  tvN               Thursday
# 4              tvN   Wednesday, Thursday
#
#    Number of Episodes       Duration  \
# 0                  10        52 min.
# 1                  16  1 hr. 10 min.
# 2                  12  1 hr. 30 min.
# 3                  12  1 hr. 40 min.
# 4                  16  1 hr. 17 min.
#
#                           Content Rating  \
# 0  18+ Restricted (violence & profanity)
# 1                15+ - Teens 15 or older
# 2                15+ - Teens 15 or older
# 3                15+ - Teens 15 or older
# 4                15+ - Teens 15 or older
#
#    Rating  \
# 0     9.2
# 1     9.1
# 2     9.1
# 3     9.1
# 4     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                      Genre  \
# 0                   Life,  Drama,  Family
# 1  Thriller,  Romance,  Crime,  Melodrama
# 2   Friendship,  Romance,  Life,  Medical
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family
#
#                                                 Tags  \
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...
# 1  Married Couple, Deception, Suspense, Family Se...
# 2  Strong Friendship, Multiple Mains, Best Friend...
# 3  Workplace, Strong Friendship, Best Friends, Mu...
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...
#
#                      Director    Screenwriter  \
# 0                 Kim Sung Ho    Yoon Ji Ryun
# 1  Kim Chul Gyu, Yoon Jong Ho    Yoo Jung Hee
# 2                 Shin Won Ho    Lee Woo Jung
# 3                 Shin Won Ho    Lee Woo Jung
# 4   Kim Won Suk, Kim Sang Woo  Park Hae Young
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 2  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                    Production companies Rank
# 0  Page One Film, Number Three Pictures   #1
# 1                         Monster Union   #2
# 2                 Egg Is Coming, CJ ENM   #3
# 3                 Egg Is Coming, CJ ENM   #4
# 4                      Chorokbaem Media   #5

# %%
kdrama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    object
#  1   Aired Date            250 non-null    object
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    object
#  4   Aired On              250 non-null    object
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    object
#  7   Content Rating        245 non-null    object
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    object
#  10  Genre                 250 non-null    object
#  11  Tags                  250 non-null    object
#  12  Director              249 non-null    object
#  13  Screenwriter          249 non-null    object
#  14  Cast                  250 non-null    object
#  15  Production companies  248 non-null    object
#  16  Rank                  250 non-null    object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 33.3+ KB

# %%
# Change the data type of Rank, Duration, Aired Date, and Split Genre

kdrama['Rank'] = kdrama['Rank'].str.replace('#','').astype(int)

kdrama['Duration_In_Hours'] = kdrama['Duration'].str.replace('min.','').str.replace('hr.','').str.replace(' ','').astype(int)

# If Duration > 100 subtract 40 from Duration

kdrama['Duration_In_Hours'] = np.where(kdrama['Duration_In_Hours'] > 100, (kdrama['Duration_In_Hours'] - 40), kdrama['Duration_In_Hours'])

kdrama[['Start_Date','End_Date']] = kdrama['Aired Date'].str.split('-',expand=True)

kdrama['Start_Date'] = pd.to_datetime(kdrama['Start_Date'])
kdrama['End_Date'] = pd.to_datetime(kdrama['End_Date'])

kdrama['Genre'] = kdrama['Genre'].str.split(',')
# Out:
# C:\Users\commo\AppData\Local\Temp\ipykernel_30948\2950700890.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   kdrama['Duration_In_Hours'] = kdrama['Duration'].str.replace('min.','').str.replace('hr.','').str.replace(' ','').astype(int)

# %%
# Show the altered columns

kdrama[['Rank','Duration_In_Hours','Start_Date','End_Date','Genre']].head()
# Out:
#    Rank  Duration_In_Hours Start_Date  \
# 0     1                 52 2021-05-14
# 1     2                 70 2020-07-29
# 2     3                 90 2020-03-12
# 3     4                100 2021-06-17
# 4     5                 77 2018-03-21
#
#     End_Date  \
# 0        NaT
# 1 2020-09-23
# 2 2020-05-28
# 3 2021-09-16
# 4 2018-05-17
#
#                                           Genre
# 0                    [Life,   Drama,   Family ]
# 1  [Thriller,   Romance,   Crime,   Melodrama ]
# 2   [Friendship,   Romance,   Life,   Medical ]
# 3   [Friendship,   Romance,   Life,   Medical ]
# 4   [Psychological,   Life,   Drama,   Family ]

# %%
kdrama.dropna(inplace=True)
kdrama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 1 to 249
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  229 non-null    object
#  1   Aired Date            229 non-null    object
#  2   Year of release       229 non-null    int64
#  3   Original Network      229 non-null    object
#  4   Aired On              229 non-null    object
#  5   Number of Episodes    229 non-null    int64
#  6   Duration              229 non-null    object
#  7   Content Rating        229 non-null    object
#  8   Rating                229 non-null    float64
#  9   Synopsis              229 non-null    object
#  10  Genre                 229 non-null    object
#  11  Tags                  229 non-null    object
#  12  Director              229 non-null    object
#  13  Screenwriter          229 non-null    object
#  14  Cast                  229 non-null    object
#  15  Production companies  229 non-null    object
#  16  Rank                  229 non-null    int32
#  17  Duration_In_Hours     229 non-null    int32
#  18  Start_Date            229 non-null    datetime64[ns]
#  19  End_Date              229 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int32(2), int64(2), object(13)
# memory usage: 35.8+ KB

# %%
kdrama.describe()
# Out:
#        Year of release  Number of Episodes  \
# count       229.000000          229.000000
# mean       2018.148472           19.925764
# std           3.213835           13.465638
# min        2003.000000            4.000000
# 25%        2017.000000           16.000000
# 50%        2019.000000           16.000000
# 75%        2021.000000           20.000000
# max        2022.000000          133.000000
#
#            Rating        Rank  Duration_In_Hours
# count  229.000000  229.000000         229.000000
# mean     8.532314  125.563319          51.100437
# std      0.216236   71.840049          25.131818
# min      8.300000    2.000000          12.000000
# 25%      8.300000   65.000000          20.000000
# 50%      8.500000  124.000000          60.000000
# 75%      8.700000  186.000000          70.000000
# max      9.100000  250.000000         100.000000

# %%
# Scatterplot of Rank vs Duration

sns.scatterplot(x='Rank',y='Duration_In_Hours',data=kdrama)

# Smooth the scatterplot with a line 

sns.regplot(x='Rank',y='Duration_In_Hours',data=kdrama)
# Out:
# <AxesSubplot: xlabel='Rank', ylabel='Duration_In_Hours'>

# %% [markdown]
# # Ideas for a Write-Up / Analysis
#
# 1. What company produces the most top shows
#
# 2. When did the top shows release
#
# 3. What genre of shows were popular
#
# 4. Any recurring cast members
#
# 5. Any reccuring directors or screenwriters
#
# 6. When did people decide to watch the shows

# %%
# Split the Original Network column and One Hot Encode it for each network

kdrama['Original Network'] = kdrama['Original Network'].str.split(',')

kdrama_exploded = kdrama.explode('Original Network')

kdrama_exploded.head(1)
# Out:
#              Name                   Aired Date  \
# 1  Flower of Evil  Jul 29, 2020 - Sep 23, 2020
#
#    Year of release  Original Network  \
# 1             2020               NaN
#
#                Aired On  Number of Episodes  \
# 1   Wednesday, Thursday                  16
#
#         Duration           Content Rating  \
# 1  1 hr. 10 min.  15+ - Teens 15 or older
#
#    Rating  \
# 1     9.1
#
#                                             Synopsis  \
# 1  Although Baek Hee Sung is hiding a dark secret...
#
#                                           Genre  \
# 1  [Thriller,   Romance,   Crime,   Melodrama ]
#
#                                                 Tags  \
# 1  Married Couple, Deception, Suspense, Family Se...
#
#                      Director  Screenwriter  \
# 1  Kim Chul Gyu, Yoon Jong Ho  Yoo Jung Hee
#
#                                                 Cast  \
# 1  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
#
#   Production companies  Rank  Duration_In_Hours  \
# 1        Monster Union     2                 70
#
#   Start_Date   End_Date
# 1 2020-07-29 2020-09-23

# %%
kdrama_exploded['Original Network'] = kdrama_exploded['Original Network'].str.strip()

# %%
plt.figure(figsize=(5,5))
kdrama_exploded.groupby('Original Network')['Rank'].count().sort_values(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='Original Network'>

# %%
plt.figure(figsize=(5,5))
kdrama['Year of release'].value_counts().sort_index(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
# Make a Ridge Line Plot of the Duration vs Year of Release using joypy

import joypy

fig, axes = joypy.joyplot(kdrama, by="Year of release", column="Duration_In_Hours", ylim='own', figsize=(5,5), linewidth=1, legend=False, fade=True, x_range=(0, 150))
