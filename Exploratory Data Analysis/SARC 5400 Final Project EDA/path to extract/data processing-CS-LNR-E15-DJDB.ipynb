# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

path = r'path to extract\\'

# %%
country_conflicts = pd.read_csv('Country Conflicts.csv')
print(country_conflicts.isna().sum())
country_conflicts.head(5)
# Out:
# Country                                                                          0
# Country Abbreviation                                                             0
# Year                                                                             0
# Deaths in ongoing conflicts in a country (best estimate) - Conflict type: all    0
# dtype: int64
#     Country Country Abbreviation  Year  \
# 0  Abkhazia             OWID_ABK  1989
# 1  Abkhazia             OWID_ABK  1990
# 2  Abkhazia             OWID_ABK  1991
# 3  Abkhazia             OWID_ABK  1992
# 4  Abkhazia             OWID_ABK  1993
#
#    Deaths in ongoing conflicts in a country (best estimate) - Conflict type: all
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0

# %%
fragile_state = pd.read_csv("Fragile State Index.csv")
print(fragile_state.isna().sum())
fragile_state.head(5)
# Out:
# Country                         0
# Year                            0
# Rank                            0
# Security Apparatus              0
# Factionalized Elites            0
# Group Grievance                 0
# Economy                         0
# Economic Inequality             0
# Human Flight and Brain Drain    0
# State Legitimacy                0
# Public Services                 0
# Human Rights                    0
# Demographic Pressures           0
# Refugees and IDPs               0
# External Intervention           0
# Total                           0
# dtype: int64
#                      Country  Year Rank  Security Apparatus  \
# 0                      Sudan  2006  1st                 9.8
# 1  Congo Democratic Republic  2006  2nd                 9.8
# 2              Cote d'Ivoire  2006  3rd                 9.8
# 3                       Iraq  2006  4th                 9.8
# 4                   Zimbabwe  2006  5th                 9.4
#
# ...

# %%
# print the len of countries in both datasets
print(len(country_conflicts['Country'].unique()))
print(len(fragile_state['Country'].unique()))

# print len intersection
print(len(set(country_conflicts['Country']).intersection(set(fragile_state['Country']))))
# Out:
# 205
# 187
# 173

# %%
gender_gap_index = pd.read_csv("Gender Gap Index.csv")
print(gender_gap_index.isna().sum())
gender_gap_index.head(5)
# Out:
# country              0
# Code                 0
# Year                 0
# Gender wage gap %    0
# dtype: int64
#   country Code  Year  Gender wage gap %
# 0  Brazil  BRA  1981              34.21
# 1  Brazil  BRA  1982              33.66
# 2  Brazil  BRA  1983              35.75
# 3  Brazil  BRA  1984              34.04
# 4  Brazil  BRA  1985              28.58

# %%
#  len of gender gap
print(len(gender_gap_index['country'].unique()))
# Out:
# 64

# %%
internet_prices = pd.read_csv("Internet Prices.csv")
print(internet_prices.isna().sum())
print(len(internet_prices['Country'].unique()))
internet_prices.head(5)
# Out:
# City                     0
# Region                  92
# Country                  0
# Internet Price, 2010     0
# Internet Price, 2011     0
# Internet Price, 2012     0
# Internet Price, 2013     0
# Internet Price, 2014     0
# Internet Price, 2015     0
# Internet Price, 2016     0
# Internet Price, 2017     0
# Internet Price, 2018     0
# Internet Price, 2019     0
# Internet Price, 2020     0
# dtype: int64
# 123
#                City                Region                   Country  \
# 0     New York City              New York  United States of America
# 1  Washington, D.C.  District of Columbia  United States of America
# 2     San Francisco            California  United States of America
# 3            Berlin                   NaN                   Germany
# 4       Los Angeles            California  United States of America
#
#    Internet Price, 2010  Internet Price, 2011  Internet Price, 2012  \
# 0             42.990000             49.998333             42.250000
# ...

# %%
passport_index = pd.read_csv("Passport Index.csv")
print(passport_index.isna().sum())
print(len(passport_index['COUNTRY'].unique()))
passport_index.head(5)
# Out:
# COUNTRY                  0
# RANK                     0
# ACCESS TO COUNTRIES    382
# YEAR                     0
# dtype: int64
# 200
#        COUNTRY RANK ACCESS TO COUNTRIES  YEAR
# 0        Japan    1                 192  2022
# 1    Singapore    1                 192  2022
# 2      Germany    2                 190  2022
# 3  South Korea    2                 190  2022
# 4      Finland    3                 189  2022

# %%
# show the rows wehre isna
passport_index[passport_index.isna().any(axis=1)]["YEAR"].value_counts()
# Out:
# YEAR
# 2009    198
# 2007    184
# Name: count, dtype: int64

# %%
world_indexes = pd.read_csv("World Indexes.csv")
print(world_indexes.isna().sum())
print(len(world_indexes['Country'].unique()))
world_indexes.head(5)
# Out:
# Rank                              0
# Country                           0
# Quality of Life Index             0
# Purchasing Power Index            0
# Safety Index                      0
# Health Care Index                 0
# Cost of Living Index              0
# Property Price to Income Ratio    0
# Traffic Commute Time Index        0
# Pollution Index                   0
# Climate Index                     0
# Year                              0
# dtype: int64
# 92
#    Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 0     1  Switzerland                 190.82                  110.96
# 1     2      Denmark                 190.01                   94.73
# 2     3  Netherlands                 183.31                   83.89
# 3     4      Finland                 182.79                   89.05
# 4     5      Austria                 182.37                   78.23
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# ...

# %%
world_indexes.sort_values(by='Purchasing Power Index', inplace=True, ascending=True)
world_indexes_2019 = world_indexes[world_indexes["Year"] == 2019]

# %%
# Economic indicators
economic_indicators = ['Purchasing Power Index', 'Cost of Living Index', 'Safety Index', 'Health Care Index',]

# Humanitarian indicators
humanitarian_indicators = [ 'Property Price to Income Ratio','Traffic Commute Time Index', 'Pollution Index']

# %%
world_indexes_2019['Climate Index'] = world_indexes_2019['Climate Index'].str.replace(',', '.').astype(float)
# Out:
# C:\Users\djx3rn\AppData\Local\Temp\ipykernel_22072\1469827187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   world_indexes_2019['Climate Index'] = world_indexes_2019['Climate Index'].str.replace(',', '.').astype(float)

# %%
# convert to percentile rank
world_indexes_2019.iloc[:, 2:-1] = world_indexes_2019.iloc[:, 2:-1].rank(pct=True)

# %%
sns.heatmap(world_indexes_2019.iloc[:,2:-1].corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(world_indexes_2019['Quality of Life Index'], world_indexes_2019['Pollution Index'])
plt.xlabel('Quality of Life Index')
plt.ylabel('Pollution Index')
# Out:
# Text(0, 0.5, 'Pollution Index')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# plot economic of egypt
sns.barplot(data=world_indexes_2019[world_indexes_2019['Country'] == 'Egypt'][economic_indicators], ax=ax[0])
ax[0].set_title('Economic/Wellness Indicators')
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=25)
ax[0].set_ylim(0, 1)

# plot humanitarian of egypt
sns.barplot(data=world_indexes_2019[world_indexes_2019['Country'] == 'Egypt'][humanitarian_indicators], ax=ax[1])
ax[1].set_title('Humanitarian Indicators')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=25)
ax[1].set_ylim(0, 1)

plt.suptitle('Egypt Indicators')
# Out:
# C:\Users\djx3rn\AppData\Local\Temp\ipykernel_22072\3650197061.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=25)
# C:\Users\djx3rn\AppData\Local\Temp\ipykernel_22072\3650197061.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=25)
# Text(0.5, 0.98, 'Egypt Indicators')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# plot economic of egypt
sns.barplot(data=world_indexes_2019[world_indexes_2019['Country'] == 'Qatar'][economic_indicators], ax=ax[0])
ax[0].set_title('Economic/Wellness Indicators')
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=25)
ax[0].set_ylim(0, 1)

# plot humanitarian of egypt
sns.barplot(data=world_indexes_2019[world_indexes_2019['Country'] == 'Qatar'][humanitarian_indicators], ax=ax[1])
ax[1].set_title('Humanitarian Indicators')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=25)
ax[1].set_ylim(0, 1)

plt.suptitle('Qatar Indicators')
# Out:
# C:\Users\djx3rn\AppData\Local\Temp\ipykernel_22072\2061789083.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=25)
# C:\Users\djx3rn\AppData\Local\Temp\ipykernel_22072\2061789083.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=25)
# Text(0.5, 0.98, 'Qatar Indicators')

# %%
world_population = pd.read_csv("World Population.csv")
world_population.head(5)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2010  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  23356246.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2913021.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84449.0
#
#          2011        2012        2013        2014        2015        2016  \
# ...
